# %% [markdown]
# <a href="https://colab.research.google.com/github/2017130744/pandas/blob/main/07%20update%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
friend_dict_list = [
                    {'name': 'John', 'age': 15, 'job': 'student'},
                    {'name': 'Jenny', 'age': 30, 'job': 'developer'},
                    {'name': 'Nate', 'age': 30, 'job': 'teacher'}
]

df = pd.DataFrame(friend_dict_list, columns = ['name', 'age', 'job'])
df
# Out:
#     name  age        job
# 0   John   15    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher

# %%
#열 삽입하기

df['salary'] = 0
df
# Out:
#     name  age        job  salary
# 0   John   15    student       0
# 1  Jenny   30  developer       0
# 2   Nate   30    teacher       0

# %%
#학생인 사람은 연봉이 없고 학생이 아닌 사람은 연봉이 있게 설정하기

import numpy as np

df['salary'] = np.where(df['job'] != 'student', 'yes', 'no')
df
# Out:
#     name  age        job salary
# 0   John   15    student     no
# 1  Jenny   30  developer    yes
# 2   Nate   30    teacher    yes

# %%
friend_dict_list = [
                    {'name': 'John', 'midterm': 95, 'final': 85},
                    {'name': 'Jenny', 'midterm': 85, 'final': 80},
                    {'name': 'Nate', 'midterm': 30, 'final': 10}
]

df = pd.DataFrame(friend_dict_list, columns = ['name', 'midterm', 'final'])
df
# Out:
#     name  midterm  final
# 0   John       95     85
# 1  Jenny       85     80
# 2   Nate       30     10

# %%
#총점 열 추가하기

df['total'] = df['midterm'] + df['final']
df
# Out:
#     name  midterm  final  total
# 0   John       95     85    180
# 1  Jenny       85     80    165
# 2   Nate       30     10     40

# %%
#평균점수 추가하기
df['mean'] = df['total']/ 2
df
# Out:
#     name  midterm  final  total  mean
# 0   John       95     85    180  90.0
# 1  Jenny       85     80    165  82.5
# 2   Nate       30     10     40  20.0

# %%
## 반복문 이용하여 학점 부여하기

grades= []
for row in df['mean']:
  if row >= 90:
    grades.append('A')
  elif row >=80:
    grades.append('B')
  else:
    grades.append('F')

df['grade'] = grades
df
# Out:
#     name  midterm  final  total  mean grade
# 0   John       95     85    180  90.0     A
# 1  Jenny       85     80    165  82.5     B
# 2   Nate       30     10     40  20.0     F

# %%
## 학점에 따라 p/f 부여하기

def pass_or_fail(row):
  if row != 'F':
    return "Pass"
  else:
    return "Fail"

#apply함수: 각 row마다 함수 인자에 해당하는 함수를 실행.
df.grade = df.grade.apply(pass_or_fail)
df
# Out:
#     name  midterm  final  total  mean grade
# 0   John       95     85    180  90.0  Pass
# 1  Jenny       85     80    165  82.5  Pass
# 2   Nate       30     10     40  20.0  Fail

# %%
date_list = [
             {
                 'yyyy-mm-dd': '2000-06-27'
             },
             {
                 'yyyy-mm-dd': '2007-10-27'
             }
]

df = pd.DataFrame(date_list, columns = ['yyyy-mm-dd'])
df
# Out:
#    yyyy-mm-dd
# 0  2000-06-27
# 1  2007-10-27

# %%
## 연도만 빼기. 

def extract_year(row):
  return row.split('-')[0]

df['year'] = df['yyyy-mm-dd'].apply(extract_year)
df
# Out:
#    yyyy-mm-dd  year
# 0  2000-06-27  2000
# 1  2007-10-27  2007

# %%
friend_dict_list = [
                    {'name': 'John', 'midterm': 95, 'final': 85},
                    {'name': 'Jenny', 'midterm': 85, 'final': 80},
                    {'name': 'Nate', 'midterm': 30, 'final': 10}
]

df = pd.DataFrame(friend_dict_list, columns = ['name', 'midterm', 'final'])
df
# Out:
#     name  midterm  final
# 0   John       95     85
# 1  Jenny       85     80
# 2   Nate       30     10

# %%
#새로운 사람 추가하기

df2 = pd.DataFrame([['Ben', 50, 50]], columns = ['name', 'midterm', 'final'])
df2
# Out:
#   name  midterm  final
# 0  Ben       50     50

# %%
df.append(df2, ignore_index = True)
## df에도 인덱스가 0인 행이 있고 df2에도 인덱스가 0인 행이 있으므로 ignore index를 한다.
# Out:
#     name  midterm  final
# 0   John       95     85
# 1  Jenny       85     80
# 2   Nate       30     10
# 3    Ben       50     50
